# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import ShuffleSplit

from sklearn.neighbors import KNeighborsClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn import svm
from sklearn import tree
from sklearn.neural_network import MLPClassifier
from sklearn.pipeline import Pipeline
from sklearn.model_selection import learning_curve
import xgboost as xgb
from sklearn.metrics import mean_squared_error
from sklearn.metrics import explained_variance_score
from sklearn.svm import SVR
from sklearn.metrics import r2_score

# %% [markdown]
# # Read Data

# %%
# TODO: read data.csv into a dataframe (~1 line)

## END OF TODO
df = pd.read_csv('data.csv')
df.head()
# Out:
#    id  Jitter (local)  Jitter (local/absolute)  Jitter (rap)  Jitter (ppq5)  \
# 0   1           1.488                 0.000090         0.900          0.794
# 1   1           0.728                 0.000038         0.353          0.376
# 2   1           1.220                 0.000074         0.732          0.670
# 3   1           2.502                 0.000123         1.156          1.634
# 4   1           3.509                 0.000167         1.715          1.539
#
#    Jitter (ddp)  Shimmer (local)  Shimmer (local/dB)  Shimmer (apq3)  \
# 0         2.699            8.334               0.779           4.517
# 1         1.059            5.864               0.642           2.058
# 2         2.196            8.719               0.875           4.347
# 3         3.469           13.513               1.273           5.263
# 4         5.145            9.112               1.040           3.102
#
#    Shimmer (apq5)  ...    Maximum pitch  Number of pulses  Number of periods  \
# 0           4.609  ...          187.576               160                159
# 1           3.180  ...          234.505               170                169
# 2           5.166  ...          211.442              1431               1427
# 3           8.771  ...          220.230                94                 92
# 4           4.927  ...          225.162               117                114
#
#    Mean period  Standard deviation of period  \
# 0     0.006065                      0.000416
# 1     0.005181                      0.000403
# 2     0.006071                      0.000474
# 3     0.004910                      0.000320
# 4     0.004757                      0.000380
#
#    Fraction of locally unvoiced frames  Number of voice breaks  \
# 0                                0.000                       0
# 1                                2.247                       0
# 2                               10.656                       1
# 3                                0.000                       0
# 4                               18.182                       1
#
#    Degree of voice breaks   UPDRS  Class
# 0                    0.000     23      1
# 1                    0.000     23      1
# 2                    0.178     23      1
# 3                    0.000     23      1
# 4                   13.318     23      1
#
# [5 rows x 29 columns]

# %%
df.shape
# Expected output: (1040,29)
# Out:
# (1040, 29)

# %%
del df['id'] # remove subject ID column

# %%
df.describe()
# Out:
#        Jitter (local)  Jitter (local/absolute)  Jitter (rap)  Jitter (ppq5)  \
# count     1040.000000              1040.000000   1040.000000    1040.000000
# mean         2.679523                 0.000170      1.247053       1.348327
# std          1.765053                 0.000106      0.979462       1.138742
# min          0.190000                 0.000006      0.062000       0.081000
# 25%          1.507500                 0.000095      0.617000       0.665750
# 50%          2.396000                 0.000151      1.035500       1.126500
# 75%          3.411500                 0.000229      1.602500       1.694750
# max         14.376000                 0.000777      8.016000      13.542000
#
#        Jitter (ddp)  Shimmer (local)  Shimmer (local/dB)  Shimmer (apq3)  \
# count   1040.000000      1040.000000         1040.000000     1040.000000
# mean       3.741161        12.918391            1.194895        5.699600
# std        2.938443         5.452204            0.420071        3.015183
# min        0.185000         1.185000            0.103000        0.496000
# 25%        1.851750         9.353500            0.941000        3.703000
# 50%        3.107000        12.348500            1.181500        5.134500
# 75%        4.808500        15.493250            1.411000        6.942000
# max       24.048000        41.137000            2.721000       25.820000
#
#        Shimmer (apq5)  Shimmer (apq11)     ...       Maximum pitch  \
# count     1040.000000      1040.000000     ...         1040.000000
# mean         7.983552        12.215345     ...          234.875990
# std          4.840892         6.016261     ...          121.541243
# min          0.708000         0.517000     ...           85.541000
# 25%          5.160250         8.079500     ...          143.650750
# 50%          7.050500        11.418659     ...          195.971000
# 75%          9.558930        15.306125     ...          263.798250
# max         72.860000        44.764000     ...          597.974000
#
#        Number of pulses  Number of periods  Mean period  \
# count       1040.000000        1040.000000  1040.000000
# mean         109.744231         105.969231     0.006547
# std          150.027703         149.417074     0.001875
# min            0.000000           0.000000     0.002039
# 25%           42.750000          40.750000     0.005039
# 50%           65.000000          62.000000     0.006484
# 75%          113.000000         109.000000     0.007923
# max         1490.000000        1489.000000     0.012070
#
#        Standard deviation of period  Fraction of locally unvoiced frames  \
# count                   1040.000000                          1040.000000
# mean                       0.000843                            27.682856
# std                        0.000723                            20.975294
# min                        0.000055                             0.000000
# 25%                        0.000404                             8.149250
# 50%                        0.000644                            26.501000
# 75%                        0.000980                            43.064250
# max                        0.006371                            88.158000
#
#        Number of voice breaks  Degree of voice breaks         UPDRS  \
# count             1040.000000              1040.000000  1040.000000
# mean                 1.134615                12.370042    13.000000
# std                  1.614764                15.161916    15.894745
# min                  0.000000                 0.000000     1.000000
# 25%                  0.000000                 0.000000     1.000000
# 50%                  1.000000                 5.826000     3.000000
# 75%                  1.000000                22.255500    23.250000
# max                 12.000000                69.117000    55.000000
#
#              Class
# count  1040.000000
# mean      0.500000
# std       0.500241
# min       0.000000
# 25%       0.000000
# 50%       0.500000
# 75%       1.000000
# max       1.000000
#
# [8 rows x 28 columns]

# %% [markdown]
# # Split Data into Training and Testing

# %%
# TODO: extract features and labels (~3 lines)
# Use the last column for label Y. 
# The next to the last column UPDRS (Unified Parkinson's Disease Rating Scale)
# can be used in the optional problem for regression. 
# Use the rest columns for features X
X = df.drop(columns=['UPDRS','Class'])
Y = df['Class'].values

# END OF TODO 
#regression

# %%
# TODO: hold out 20% for testing using stratified sampling (~1 line)
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size = 0.2, random_state=1, stratify=Y)

# END OF TODO

# %%
nfolds = 10

# %%
X.shape # Expected outcome: (1040,26)
# Out:
# (1040, 26)

# %%
Y.shape # Expected outcome: (1040,0)
# Out:
# (1040,)

# %% [markdown]
# ## K-Nearest Neighbors (KNN)

# %%
pipe_knn = Pipeline([('scl', StandardScaler()),
                     ('knn', KNeighborsClassifier())])

# TODO: set parameter k as odd numbers from 1 to 13 (~1 line)
k = range(1, 13, 2)
print(k)
# END OF TODO 

param_grid = [{'knn__n_neighbors': k}]
# TODO: Using GridSearchCV to find the optimal k. setup n_jobs=-1 to use all CPUs (~1 line)
gs_knn = GridSearchCV(pipe_knn,
                      param_grid = param_grid,
                      scoring="f1",
                      cv=10,
                      n_jobs=-1)

# TODO: Fit the KNN grid search model to training data (~1 line)
gs_knn.fit(X_train, Y_train)
# END OF TODO

print(gs_knn.best_score_)
print(gs_knn.best_params_)
# Out:
# range(1, 13, 2)
# 0.6835894664591381
# {'knn__n_neighbors': 3}
# /anaconda3/lib/python3.7/site-packages/sklearn/model_selection/_search.py:841: DeprecationWarning: The default of the `iid` parameter will change from True to False in version 0.22 and will be removed in 0.24. This will change numeric results when test-set sizes are unequal.
#   DeprecationWarning)
# /anaconda3/lib/python3.7/site-packages/sklearn/preprocessing/data.py:625: DataConversionWarning: Data with input dtype int64, float64 were all converted to float64 by StandardScaler.
#   return self.partial_fit(X, y)
# /anaconda3/lib/python3.7/site-packages/sklearn/base.py:465: DataConversionWarning: Data with input dtype int64, float64 were all converted to float64 by StandardScaler.
#   return self.fit(X, y, **fit_params).transform(X)

# %%
clf_knn = gs_knn.best_estimator_
clf_knn.fit(X_test, Y_test)
print('Test accuracy: %.3f' % clf_knn.score(X_test, Y_test))
# Out:
# Test accuracy: 0.798
# /anaconda3/lib/python3.7/site-packages/sklearn/preprocessing/data.py:625: DataConversionWarning: Data with input dtype int64, float64 were all converted to float64 by StandardScaler.
#   return self.partial_fit(X, y)
# /anaconda3/lib/python3.7/site-packages/sklearn/base.py:465: DataConversionWarning: Data with input dtype int64, float64 were all converted to float64 by StandardScaler.
#   return self.fit(X, y, **fit_params).transform(X)
# /anaconda3/lib/python3.7/site-packages/sklearn/pipeline.py:511: DataConversionWarning: Data with input dtype int64, float64 were all converted to float64 by StandardScaler.
#   Xt = transform.transform(Xt)

# %% [markdown]
# ## Support Vector Machines (SVM)

# %%
# TODO: Build a pipeline including a standard scaler and SVC classifier (~1 line)
from sklearn.svm import SVC
pipe_svc = Pipeline([('scl', StandardScaler()),
                         ('clf', SVC(random_state=1))])

# END OF TODO

param_range = [0.0001, 0.001, 0.01, 0.1, 1.0, 10.0, 100.0, 1000.0]

# TODO: Use GridSearchCV to find optimal kernel (linear or rbf), C (param_range), and/or gamma (param_range) (~3 lines)
param_grid = [
    {'clf__C': param_range, 'clf__kernel': ['linear']}, 
    {'clf__C': param_range, 'clf__gamma': param_range, 'clf__kernel': ['rbf']} 
]

gs_svm = GridSearchCV(estimator=pipe_svc,
                  param_grid=param_grid,
                  scoring='accuracy',
                  cv=10,
                  n_jobs=-1)
gs_svm = gs_svm.fit(X_train, Y_train)


# END OF TODO

print(gs_svm.best_score_)
print(gs_svm.best_params_)
# Out:
# 0.6802884615384616
# {'clf__C': 10.0, 'clf__gamma': 0.1, 'clf__kernel': 'rbf'}
# /anaconda3/lib/python3.7/site-packages/sklearn/model_selection/_search.py:841: DeprecationWarning: The default of the `iid` parameter will change from True to False in version 0.22 and will be removed in 0.24. This will change numeric results when test-set sizes are unequal.
#   DeprecationWarning)
# /anaconda3/lib/python3.7/site-packages/sklearn/preprocessing/data.py:625: DataConversionWarning: Data with input dtype int64, float64 were all converted to float64 by StandardScaler.
#   return self.partial_fit(X, y)
# /anaconda3/lib/python3.7/site-packages/sklearn/base.py:465: DataConversionWarning: Data with input dtype int64, float64 were all converted to float64 by StandardScaler.
#   return self.fit(X, y, **fit_params).transform(X)

# %%
clf_svm = gs_svm.best_estimator_
clf_svm.fit(X_train, Y_train)
print('Test accuracy: %.3f' % clf_svm.score(X_test, Y_test))
# Out:
# Test accuracy: 0.731
# /anaconda3/lib/python3.7/site-packages/sklearn/preprocessing/data.py:625: DataConversionWarning: Data with input dtype int64, float64 were all converted to float64 by StandardScaler.
#   return self.partial_fit(X, y)
# /anaconda3/lib/python3.7/site-packages/sklearn/base.py:465: DataConversionWarning: Data with input dtype int64, float64 were all converted to float64 by StandardScaler.
#   return self.fit(X, y, **fit_params).transform(X)
# /anaconda3/lib/python3.7/site-packages/sklearn/pipeline.py:511: DataConversionWarning: Data with input dtype int64, float64 were all converted to float64 by StandardScaler.
#   Xt = transform.transform(Xt)

# %% [markdown]
# ## Naive Bayes (NB)

# %%
# TODO: Build a Naive Bayes classifier (no hyper-parameters) (~2 lines)
clf_nb = GaussianNB()
clf_nb.fit(X_train, Y_train);

# END OF TODO

# %%
print(clf_nb.score(X_test,Y_test))
# Out:
# 0.5625

# %% [markdown]
# ## Neural Networks (NN)

# %%
# TODO: Use MLPClassifier to build a neural network.(~2 lines)
# Try different hyper-parameters of # of layers and # of nodes in each layer
mlp = MLPClassifier(hidden_layer_sizes=(30,30,30), max_iter=500, alpha=0.0001,
                     solver='sgd', verbose=10,  random_state=21,tol=0.000000001)
clf_nn = mlp.fit(X_train,Y_train)
mlp2 = MLPClassifier(hidden_layer_sizes=(100,100,100), max_iter=500, alpha=0.0001,
                     solver='sgd', verbose=10,  random_state=21,tol=0.000000001)
clf_nn2 = mlp2.fit(X_train,Y_train)

mlp3 = MLPClassifier(hidden_layer_sizes=(300,300,300), max_iter=500, alpha=0.0001,
                     solver='sgd', verbose=10,  random_state=21,tol=0.000000001)
clf_nn3 = mlp3.fit(X_train,Y_train)
# END OF TODO
# Out:
# Iteration 1, loss = 9.53448280
# Iteration 2, loss = 1.23962325
# Iteration 3, loss = 0.80336445
# Iteration 4, loss = 0.76558646
# Iteration 5, loss = 0.77929122
# Iteration 6, loss = 0.73482517
# Iteration 7, loss = 0.69040334
# Iteration 8, loss = 0.68258945
# Iteration 9, loss = 0.69531318
# Iteration 10, loss = 0.67105237
# Iteration 11, loss = 0.67078046
# Iteration 12, loss = 0.66176238
# Iteration 13, loss = 0.66723288
# Iteration 14, loss = 0.67041415
# Iteration 15, loss = 0.65867459
# Iteration 16, loss = 0.66330250
# Iteration 17, loss = 0.69044824
# Iteration 18, loss = 0.66646722
# Iteration 19, loss = 0.68462789
# Iteration 20, loss = 0.66479146
# Iteration 21, loss = 0.65645936
# Iteration 22, loss = 0.65140632
# Iteration 23, loss = 0.65505098
# Iteration 24, loss = 0.67034585
# Iteration 25, loss = 0.65886734
# Iteration 26, loss = 0.65524122
# Iteration 27, loss = 0.65859799
# Iteration 28, loss = 0.65315885
# Iteration 29, loss = 0.64645158
# Iteration 30, loss = 0.64847150
# Iteration 31, loss = 0.66190859
# Iteration 32, loss = 0.66613944
# Iteration 33, loss = 0.64753002
# Iteration 34, loss = 0.65267937
# Iteration 35, loss = 0.65762836
# Iteration 36, loss = 0.66043576
# Iteration 37, loss = 0.65478373
# Iteration 38, loss = 0.65300717
# Iteration 39, loss = 0.64864681
# Iteration 40, loss = 0.65315540
# Training loss did not improve more than tol=0.000000 for 10 consecutive epochs. Stopping.
# Iteration 1, loss =
# Iteration 67, loss = 0.58917092
# Iteration 68, loss = 0.57631446
# Iteration 69, loss = 0.56805214
# Iteration 70, loss = 0.56874044
# Iteration 71, loss = 0.56799120
# Iteration 72, loss = 0.58367795
# Iteration 73, loss = 0.57890708
# Iteration 74, loss = 0.62789198
# Iteration 75, loss = 0.58855828
# Iteration 76, loss = 0.56176978
# Iteration 77, loss = 0.56896723
# Iteration 78, loss = 0.55654068
# Iteration 79, loss = 0.55307864
# Iteration 80, loss = 0.55679991
# Iteration 81, loss = 0.56949534
# Iteration 82, loss = 0.56063314
# Iteration 83, loss = 0.55220775
# Iteration 84, loss = 0.58939527
# Iteration 85, loss = 0.55666522
# Iteration 86, loss = 0.57530313
# Iteration 87, loss = 0.66157792
# Iteration 88, loss = 0.55997761
# Iteration 89, loss = 0.61107725
# Iteration 90, loss = 0.58308895
# Iteration 91, loss = 0.60163389
# Iteration 92, loss = 0.56064844
# Iteration 93, loss = 0.56185747
# Iteration 94, loss = 0.55939022
# Training loss did not improve more than tol=0.000000 for 10 consecutive epochs. Stopping.

# %%
print(clf_nn.score(X_test,Y_test))
print(clf_nn2.score(X_test,Y_test))
print(clf_nn3.score(X_test,Y_test))
# Out:
# 0.5721153846153846
# 0.5961538461538461
# 0.6346153846153846

# %% [markdown]
# ## Decision Tree

# %%
## TODO: Use tree.DecisionTreeClassifier to build a decision tree using training data (~2 lines)
from sklearn.tree import DecisionTreeClassifier, export_graphviz
dt = DecisionTreeClassifier()
clf_dt=dt.fit(X_train,Y_train)

## END OF TODO
print(clf_dt.score(X_test,Y_test))
# Out:
# 0.6201923076923077

# %% [markdown]
# ## Visualize the tree

# %%
import graphviz as gv
dot_data = tree.export_graphviz(clf_dt, out_file=None) 
graph = gv.Source(dot_data) 
graph.render("Parkinson Decision Tree")
feature_names = list(df.iloc[:, 0:-2].head())
print(feature_names)
# Out:
# ['Jitter (local)', 'Jitter (local/absolute)', 'Jitter (rap)', 'Jitter (ppq5)', 'Jitter (ddp)', 'Shimmer (local)', 'Shimmer (local/dB)', 'Shimmer (apq3)', 'Shimmer (apq5)', 'Shimmer (apq11)', 'Shimmer (dda)', ' AC', 'NTH', 'HTN', 'Median pitch', 'Mean pitch', 'Standard deviation', 'Minimum pitch', 'Maximum pitch', 'Number of pulses', 'Number of periods', 'Mean period', 'Standard deviation of period', 'Fraction of locally unvoiced frames', 'Number of voice breaks', 'Degree of voice breaks ']

# %%
dot_data = tree.export_graphviz(clf_dt, out_file=None,
                                feature_names=feature_names,
                                class_names=['HC','PD'],
                                filled=True,
                                rounded=True)  
graph = gv.Source(dot_data)
graph

# %% [markdown]
# # Learning Curve

# %%
def plot_learning_curve(estimator, title, X, y, ylim=None, cv=None,
                        n_jobs=None, train_sizes=np.linspace(.1, 1.0, 5)):
    """
    Generate a simple plot of the test and training learning curve.

    Parameters
    ----------
    estimator : object type that implements the "fit" and "predict" methods
        An object of that type which is cloned for each validation.

    title : string
        Title for the chart.

    X : array-like, shape (n_samples, n_features)
        Training vector, where n_samples is the number of samples and
        n_features is the number of features.

    y : array-like, shape (n_samples) or (n_samples, n_features), optional
        Target relative to X for classification or regression;
        None for unsupervised learning.

    ylim : tuple, shape (ymin, ymax), optional
        Defines minimum and maximum yvalues plotted.

    cv : int, cross-validation generator or an iterable, optional
        Determines the cross-validation splitting strategy.
        Possible inputs for cv are:
          - None, to use the default 3-fold cross-validation,
          - integer, to specify the number of folds.
          - :term:`CV splitter`,
          - An iterable yielding (train, test) splits as arrays of indices.

        For integer/None inputs, if ``y`` is binary or multiclass,
        :class:`StratifiedKFold` used. If the estimator is not a classifier
        or if ``y`` is neither binary nor multiclass, :class:`KFold` is used.

        Refer :ref:`User Guide <cross_validation>` for the various
        cross-validators that can be used here.

    n_jobs : int or None, optional (default=None)
        Number of jobs to run in parallel.
        ``None`` means 1 unless in a :obj:`joblib.parallel_backend` context.
        ``-1`` means using all processors. See :term:`Glossary <n_jobs>`
        for more details.

    train_sizes : array-like, shape (n_ticks,), dtype float or int
        Relative or absolute numbers of training examples that will be used to
        generate the learning curve. If the dtype is float, it is regarded as a
        fraction of the maximum size of the training set (that is determined
        by the selected validation method), i.e. it has to be within (0, 1].
        Otherwise it is interpreted as absolute sizes of the training sets.
        Note that for classification the number of samples usually have to
        be big enough to contain at least one sample from each class.
        (default: np.linspace(0.1, 1.0, 5))
    """
    plt.figure()
    plt.title(title)
    if ylim is not None:
        plt.ylim(*ylim)
    plt.xlabel("Training examples")
    plt.ylabel("Score")
    train_sizes, train_scores, test_scores = learning_curve(
        estimator, X, y, cv=cv, n_jobs=n_jobs, train_sizes=train_sizes)
    train_scores_mean = np.mean(train_scores, axis=1)
    train_scores_std = np.std(train_scores, axis=1)
    test_scores_mean = np.mean(test_scores, axis=1)
    test_scores_std = np.std(test_scores, axis=1)
    plt.grid()

    plt.fill_between(train_sizes, train_scores_mean - train_scores_std,
                     train_scores_mean + train_scores_std, alpha=0.1,
                     color="r")
    plt.fill_between(train_sizes, test_scores_mean - test_scores_std,
                     test_scores_mean + test_scores_std, alpha=0.1, color="g")
    plt.plot(train_sizes, train_scores_mean, 'o-', color="r",
             label="Training score")
    plt.plot(train_sizes, test_scores_mean, 'o-', color="g",
             label="Cross-validation score")

    plt.legend(loc="best")
    return plt

# %%
title = "Learning Curves (KNN)"
# Cross validation with 100 iterations to get smoother mean test and train
# score curves, each time with 20% data randomly selected as a validation set.
cv = ShuffleSplit(n_splits=100, test_size=0.2, random_state=1)
estimator = gs_knn.best_estimator_
plot_learning_curve(estimator, title, X, Y, ylim=(0.4, 1.02), cv=cv, n_jobs=-1)
plt.show()

# %%
## TODO: Plot the learning and cross-validaiton curves for SVM (~4 lines)
title = "Learning Curves (SVM)"
# Cross validation with 100 iterations to get smoother mean test and train
# score curves, each time with 20% data randomly selected as a validation set.
cv = ShuffleSplit(n_splits=100, test_size=0.2, random_state=1)
estimator = gs_svm.best_estimator_
plot_learning_curve(estimator, title, X, Y, ylim=(0.4, 1.02), cv=cv, n_jobs=-1)
plt.show()
# END OF TODO

# %%
## TODO: Plot the learning and cross-validaiton curves for Naive Bayes (~4 lines)
title = "Learning Curves (Naive Bayes)"
# Cross validation with 100 iterations to get smoother mean test and train
# score curves, each time with 20% data randomly selected as a validation set.
cv = ShuffleSplit(n_splits=100, test_size=0.2, random_state=0)
estimator = GaussianNB()
plot_learning_curve(estimator, title, X, Y, ylim=(0.0, 1.01), cv=cv, n_jobs=4)
plt.show()
# END OF TODO

# %%
## TODO: Plot the learning and cross-validaiton curves for Neural Networks (~4 lines)

title = "Learning Curves (Neural Networks)"
# Cross validation with 100 iterations to get smoother mean test and train
# score curves, each time with 20% data randomly selected as a validation set.
cv = ShuffleSplit(n_splits=100, test_size=0.2, random_state=0)
mlp = MLPClassifier(hidden_layer_sizes=(100,100,100))
plot_learning_curve(mlp, title, X, Y, ylim=(0.0, 1.01), cv=cv, n_jobs=4)
plt.show()


# END OF TODO

# %%
## TODO: Plot the learning and cross-validaiton curves for Decision Tree (~4 lines)
title = "Learning Curves (Decision Tree)"
# Cross validation with 100 iterations to get smoother mean test and train
# score curves, each time with 20% data randomly selected as a validation set.


cv = ShuffleSplit(n_splits=100, test_size=0.2, random_state=0)
dt = DecisionTreeClassifier()
plot_learning_curve(dt, title, X, Y, ylim=(0.0, 1.01), cv=cv, n_jobs=4)
plt.show()

# END OF TODO

# %%
#XGBoost regression
title = "XGBoost Regression"
data_dmatrix = xgb.DMatrix(data=X_train,label=Y_train)
xg_reg = xgb.XGBRegressor(objective ='reg:linear', colsample_bytree = 0.3, learning_rate = 0.1,
                max_depth = 5, alpha = 10, n_estimators = 10)
clf_xgb = xg_reg.fit(X_train,Y_train)

preds = xg_reg.predict(X_test)

print(explained_variance_score(preds,Y_test))
print(clf_xgb.score(X_test,Y_test))
# Out:
# -13.432242426955728
# 0.13623988122391328

# %%
xg_reg2 = xgb.XGBRegressor(n_estimators=300, learning_rate=0.08, gamma=0, subsample=0.75,
                           colsample_bytree=1, max_depth=7)
clf_xgb2 = xg_reg2.fit(X_train,Y_train)
predictions = xg_reg2.predict(X_test)

print(explained_variance_score(predictions,Y_test))
print(clf_xgb2.score(X_test,Y_test))
# Out:
# -1.3119662206613687
# 0.24873163618508032

# %%
#k-folded
params = {"objective":"reg:linear",'colsample_bytree': 0.3,'learning_rate': 0.1,
                'max_depth': 5, 'alpha': 10}

cv_results = xgb.cv(dtrain=data_dmatrix, params=params, nfold=3,
                    num_boost_round=50,early_stopping_rounds=10,metrics="rmse", as_pandas=True, seed=123)
print((cv_results["test-rmse-mean"]).tail(1))
# Out:
# [10:43:44] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 28 extra nodes, 0 pruned nodes, max_depth=5
# [10:43:44] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 16 extra nodes, 0 pruned nodes, max_depth=5
# [10:43:44] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 28 extra nodes, 0 pruned nodes, max_depth=5
# [10:43:44] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 24 extra nodes, 0 pruned nodes, max_depth=5
# [10:43:44] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 18 extra nodes, 0 pruned nodes, max_depth=5
# [10:43:44] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 22 extra nodes, 0 pruned nodes, max_depth=5
# [10:43:44] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 28 extra nodes, 0 pruned nodes, max_depth=5
# [10:43:44] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 28 extra nodes, 0 pruned nodes, max_depth=5
# [10:43:44] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 24 extra nodes, 0 pruned nodes, max_depth=5
# [10:43:44] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 24 extra nodes, 0 pruned nodes, max_depth=5
# [10:43:44] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 16 extra nodes, 0 pruned nodes, max_depth=5
# [10:43:44] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 20 extra nodes, 0 pruned nodes, max_depth=5
# [10:43:44] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 18 extra nodes, 0 pruned nodes, max_depth=5
# [10:43:44] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 22 extra nodes, 0 pruned nodes, max_depth=5
# [10:43:44] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 28 extra nodes, 0 pruned nodes, max_depth=5
# [10:43:44] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=5
# [10:43:44] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 24 extra nodes, 0 pruned nodes, max_depth=5
# [10:43:44] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 20 extra nodes, 0 pruned nodes, max_depth=5
# [10:43:44] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 26 extra nodes, 0 pruned nodes, max_depth=5
# [10:43:44] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 28 extra nodes, 0 pruned nodes, max_depth=5
# [10:43:44] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 18 extra nodes, 0 pruned nodes, max_depth=5
# [10:43:44] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 18 extra nodes, 0 pruned nodes, max_depth=5
# [10:43:44] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 24 extra nodes, 0 pruned nodes, max_depth=5
# [10:43:44] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 24 extra nodes, 0 pruned nodes, max_depth=5
# [10:43:44] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 18 extra nodes, 0 pruned nodes, max_depth=5
# [10:43:44] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 24 extra nodes, 0 pruned nodes, max_depth=5
# [10:43:44] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 24 extra nodes, 0 pruned nodes, max_depth=5
# [10:43:44] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 26 extra nodes, 0 pruned nodes, max_depth=5
# [10:43:44] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 18 extra nodes, 0 pruned nodes, max_depth=5
# [10:43:44] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 20 extra nodes, 0 pruned nodes, max_depth=5
# [10:43:44] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 18 extra nodes, 0 pruned nodes, max_depth=5
# [10:43:44] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 24 extra nodes, 0 pruned nodes, max_depth=5
# [10:43:44] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 18 extra nodes, 0 pruned nodes, max_depth=5
# [10:43:44] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 18 extra nodes, 0 pruned nodes, max_depth=5
# [10:43:44] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=4
# [10:43:44] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 26 extra nodes, 0 pruned nodes, max_depth=5
# [10:43:44] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 28 extra nodes, 0 pruned nodes, max_depth=5
# [10:43:44] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 24 extra nodes, 0 pruned nodes, max_depth=5
# [10:43:44] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 18 extra nodes, 0 pruned nodes, max_depth=5
# [10:43:44] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 22 extra nodes, 0 pruned nodes, max_depth=5
# [10:43:44] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 24 extra nodes, 0 pruned nodes, max_depth=5
# [10:43:44] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 18 extra nodes, 0 pruned nodes, max_depth=5
# [10:43:44] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 18 extra nodes, 0 pruned nodes, max_depth=5
# [10:43:44] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 26 extra nodes, 0 pruned nodes, max_depth=5
# [10:43:44] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 22 extra nodes, 0 pruned nodes, max_depth=5
# [10:43:44] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 18 extra nodes, 0 pruned nodes, max_depth=5
# [10:43:44] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 18 extra nodes, 0 pruned nodes, max_depth=5
# [10:43:44] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 20 extra nodes, 0 pruned nodes, max_depth=5
# [10:43:44] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 18 extra nodes, 0 pruned nodes, max_depth=5
# [10:43:44] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 18 extra nodes, 0 pruned nodes, max_depth=5
# [10:43:44] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=5
# [10:43:44] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 16 extra nodes, 0 pruned nodes, max_depth=5
# [10:43:44] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 24 extra nodes, 0 pruned nodes, max_depth=5
# [10:43:44] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 24 extra nodes, 0 pruned nodes, max_depth=5
# [10:43:44] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 16 extra nodes, 0 pruned nodes, max_depth=5
# [10:43:44] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 16 extra nodes, 0 pruned nodes, max_depth=5
# [10:43:44] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 20 extra nodes, 0 pruned nodes, max_depth=5
# [10:43:44] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 24 extra nodes, 0 pruned nodes, max_depth=5
# [10:43:44] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 18 extra nodes, 0 pruned nodes, max_depth=5
# [10:43:44] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 24 extra nodes, 0 pruned nodes, max_depth=5
# [10:43:44] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 18 extra nodes, 0 pruned nodes, max_depth=5
# [10:43:44] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 18 extra nodes, 0 pruned nodes, max_depth=5
# [10:43:44] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 16 extra nodes, 0 pruned nodes, max_depth=5
# [10:43:44] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 18 extra nodes, 0 pruned nodes, max_depth=5
# [10:43:44] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 22 extra nodes, 0 pruned nodes, max_depth=5
# [10:43:44] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 28 extra nodes, 0 pruned nodes, max_depth=5
# [10:43:44] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 28 extra nodes, 0 pruned nodes, max_depth=5
# [10:43:44] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 18 extra nodes, 0 pruned nodes, max_depth=5
# [10:43:44] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 24 extra nodes, 0 pruned nodes, max_depth=5
# [10:43:44] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 24 extra nodes, 0 pruned nodes, max_depth=5
# [10:43:44] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 18 extra nodes, 0 pruned nodes, max_depth=5
# [10:43:44] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 18 extra nodes, 0 pruned nodes, max_depth=5
# [10:43:44] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 28 extra nodes, 0 pruned nodes, max_depth=5
# [10:43:44] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 22 extra nodes, 0 pruned nodes, max_depth=5
# [10:43:44] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 22 extra nodes, 0 pruned nodes, max_depth=5
# [10:43:44] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 24 extra nodes, 0 pruned nodes, max_depth=5
# [10:43:44] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 18 extra nodes, 0 pruned nodes, max_depth=5
# [10:43:44] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 26 extra nodes, 0 pruned nodes, max_depth=5
# [10:43:44] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 28 extra nodes, 0 pruned nodes, max_depth=5
# [10:43:44] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 18 extra nodes, 0 pruned nodes, max_depth=5
# [10:43:44] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 24 extra nodes, 0 pruned nodes, max_depth=5
# [10:43:44] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 16 extra nodes, 0 pruned nodes, max_depth=5
# [10:43:44] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 24 extra nodes, 0 pruned nodes, max_depth=5
# [10:43:44] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 18 extra nodes, 0 pruned nodes, max_depth=5
# [10:43:44] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 24 extra nodes, 0 pruned nodes, max_depth=5
# [10:43:44] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 18 extra nodes, 0 pruned nodes, max_depth=5
# [10:43:44] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 22 extra nodes, 0 pruned nodes, max_depth=5
# [10:43:44] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 24 extra nodes, 0 pruned nodes, max_depth=5
# [10:43:44] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 28 extra nodes, 0 pruned nodes, max_depth=5
# [10:43:44] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 22 extra nodes, 0 pruned nodes, max_depth=5
# [10:43:44] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 28 extra nodes, 0 pruned nodes, max_depth=5
# [10:43:44] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 18 extra nodes, 0 pruned nodes, max_depth=5
# [10:43:44] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 20 extra nodes, 0 pruned nodes, max_depth=5
# [10:43:44] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 18 extra nodes, 0 pruned nodes, max_depth=5
# [10:43:44] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 18 extra nodes, 0 pruned nodes, max_depth=5
# [10:43:44] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 18 extra nodes, 0 pruned nodes, max_depth=5
# [10:43:44] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 24 extra nodes, 0 pruned nodes, max_depth=5
# [10:43:44] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 18 extra nodes, 0 pruned nodes, max_depth=5
# [10:43:44] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 22 extra nodes, 0 pruned nodes, max_depth=5
# [10:43:44] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 18 extra nodes, 0 pruned nodes, max_depth=5
# [10:43:44] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 18 extra nodes, 0 pruned nodes, max_depth=5
# [10:43:44] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 16 extra nodes, 0 pruned nodes, max_depth=5
# [10:43:44] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 16 extra nodes, 0 pruned nodes, max_depth=5
# [10:43:44] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 18 extra nodes, 0 pruned nodes, max_depth=5
# [10:43:44] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 18 extra nodes, 0 pruned nodes, max_depth=5
# [10:43:44] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 18 extra nodes, 0 pruned nodes, max_depth=5
# [10:43:44] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 18 extra nodes, 0 pruned nodes, max_depth=5
# [10:43:44] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 22 extra nodes, 0 pruned nodes, max_depth=5
# [10:43:44] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 0 pruned nodes, max_depth=0
# [10:43:44] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 16 extra nodes, 0 pruned nodes, max_depth=5
# [10:43:44] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 18 extra nodes, 0 pruned nodes, max_depth=5
# [10:43:44] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 0 pruned nodes, max_depth=0
# [10:43:44] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 24 extra nodes, 0 pruned nodes, max_depth=5
# [10:43:44] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 22 extra nodes, 0 pruned nodes, max_depth=5
# [10:43:44] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 0 pruned nodes, max_depth=0
# [10:43:44] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 16 extra nodes, 0 pruned nodes, max_depth=5
# [10:43:44] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 16 extra nodes, 0 pruned nodes, max_depth=5
# [10:43:44] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 0 pruned nodes, max_depth=0
# [10:43:44] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 22 extra nodes, 0 pruned nodes, max_depth=5
# [10:43:44] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 16 extra nodes, 0 pruned nodes, max_depth=5
# [10:43:44] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 0 pruned nodes, max_depth=0
# [10:43:44] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 18 extra nodes, 0 pruned nodes, max_depth=5
# [10:43:44] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 18 extra nodes, 0 pruned nodes, max_depth=5
# [10:43:44] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 0 pruned nodes, max_depth=0
# [10:43:44] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 24 extra nodes, 0 pruned nodes, max_depth=5
# [10:43:44] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 20 extra nodes, 0 pruned nodes, max_depth=5
# [10:43:44] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 0 pruned nodes, max_depth=0
# [10:43:44] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 0 pruned nodes, max_depth=0
# [10:43:44] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 18 extra nodes, 0 pruned nodes, max_depth=5
# [10:43:44] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 0 pruned nodes, max_depth=0
# [10:43:44] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 24 extra nodes, 0 pruned nodes, max_depth=5
# [10:43:44] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 16 extra nodes, 0 pruned nodes, max_depth=5
# [10:43:44] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 0 pruned nodes, max_depth=0
# [10:43:44] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 18 extra nodes, 0 pruned nodes, max_depth=5
# [10:43:44] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 16 extra nodes, 0 pruned nodes, max_depth=5
# [10:43:44] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 0 pruned nodes, max_depth=0
# [10:43:44] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 18 extra nodes, 0 pruned nodes, max_depth=5
# [10:43:44] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 18 extra nodes, 0 pruned nodes, max_depth=5
# [10:43:44] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 0 pruned nodes, max_depth=0
# [10:43:44] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 0 pruned nodes, max_depth=0
# [10:43:44] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 24 extra nodes, 0 pruned nodes, max_depth=5
# [10:43:44] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 0 pruned nodes, max_depth=0
# [10:43:44] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 0 pruned nodes, max_depth=0
# [10:43:44] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 18 extra nodes, 0 pruned nodes, max_depth=5
# [10:43:44] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 18 extra nodes, 0 pruned nodes, max_depth=5
# [10:43:44] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 0 pruned nodes, max_depth=0
# [10:43:44] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 18 extra nodes, 0 pruned nodes, max_depth=5
# [10:43:44] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 0 pruned nodes, max_depth=0
# [10:43:44] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 24 extra nodes, 0 pruned nodes, max_depth=5
# [10:43:44] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 18 extra nodes, 0 pruned nodes, max_depth=5
# 49    0.467265
# Name: test-rmse-mean, dtype: float64

# %%
#SVM regressor
regressor=SVR(kernel='linear',degree=1)
clf_svm = regressor.fit(X_train,Y_train)
pred=regressor.predict(X_test)

print(r2_score(Y_test,pred))
print(clf_svm.score(X_test,Y_test))
# Out:
# 0.007456628372122243
# 0.007456628372122243

# %%
regressor=SVR(kernel='poly',degree=2)
clf_svm = regressor.fit(X_train,Y_train)
pred=regressor.predict(X_test)

print(r2_score(Y_test,pred))
print(clf_svm.score(X_test,Y_test))
# Out:
# /anaconda3/lib/python3.7/site-packages/sklearn/svm/base.py:196: FutureWarning: The default value of gamma will change from 'auto' to 'scale' in version 0.22 to account better for unscaled features. Set gamma explicitly to 'auto' or 'scale' to avoid this warning.
#   "avoid this warning.", FutureWarning)

# %%
print(X_train.shape)
print(Y_train.shape)
# Out:
# (832, 26)
# (832,)
